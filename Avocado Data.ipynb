# %%
import pandas as pd  # convention to import and use pandas like this

df = pd.read_csv("datasets/avocado.csv")  # df stands for dataframe. Also a common convention to call this df
df = df.copy()[df['type']=='organic']

df['Date'] = pd.to_datetime(df['Date'])   #converting date ocolumn to date object.

df.sort_values(by="Date", ascending=True, inplace=True)

# %%
df.head()
# Out:
#        Unnamed: 0       Date  AveragePrice  Total Volume       4046      4225  \
# 9489           51 2015-01-04          1.24     142349.77  107490.73  25711.96
# 10269          51 2015-01-04          1.50       6329.83    3730.80   2141.91
# 10893          51 2015-01-04          1.12      17296.85   14569.66   1868.59
# 9437           51 2015-01-04          1.73        379.82       0.00     59.82
# 11621          51 2015-01-04          1.30       5782.70     723.29   4221.15
#
#        4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 9489   2.93     9144.15     9144.15        0.00          0.0  organic  2015
# 10269  0.00      457.12      426.67       30.45          0.0  organic  2015
# 10893  0.00      858.60      830.00       28.60          0.0  organic  2015
# 9437   0.00      320.00      320.00        0.00          0.0  organic  2015
# 11621  0.00      838.26      223.33      614.93          0.0  organic  2015
#
#                  region
# ...

# %%
#We can also reference specific columns, like:
df['AveragePrice'].head()
# Out:
# 9489     1.24
# 10269    1.50
# 10893    1.12
# 9437     1.73
# 11621    1.30
# Name: AveragePrice, dtype: float64

# %%
#How to filter for a particular region
albany_df = df[df['region']=="Albany"]

# %%
albany_df.head()
# Out:
#       Unnamed: 0       Date  AveragePrice  Total Volume   4046    4225  4770  \
# 9177          51 2015-01-04          1.79       1373.95  57.42  153.88   0.0
# 9176          50 2015-01-11          1.77       1182.56  39.00  305.12   0.0
# 9175          49 2015-01-18          1.93       1118.47   8.02  178.78   0.0
# 9174          48 2015-01-25          1.89       1115.89  14.87  148.72   0.0
# 9173          47 2015-02-01          1.83       1228.51  33.12   99.36   0.0
#
#       Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  region
# 9177     1162.65     1162.65         0.0          0.0  organic  2015  Albany
# 9176      838.44      838.44         0.0          0.0  organic  2015  Albany
# 9175      931.67      931.67         0.0          0.0  organic  2015  Albany
# 9174      952.30      952.30         0.0          0.0  organic  2015  Albany
# 9173     1096.03     1096.03         0.0          0.0  organic  2015  Albany

# %%
#setting index
albany_df.set_index("Date", inplace=True)

# %%
albany_df.head()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume   4046    4225  4770  \
# Date
# 2015-01-04          51          1.79       1373.95  57.42  153.88   0.0
# 2015-01-11          50          1.77       1182.56  39.00  305.12   0.0
# 2015-01-18          49          1.93       1118.47   8.02  178.78   0.0
# 2015-01-25          48          1.89       1115.89  14.87  148.72   0.0
# 2015-02-01          47          1.83       1228.51  33.12   99.36   0.0
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# Date
# 2015-01-04     1162.65     1162.65         0.0          0.0  organic  2015
# 2015-01-11      838.44      838.44         0.0          0.0  organic  2015
# 2015-01-18      931.67      931.67         0.0          0.0  organic  2015
# 2015-01-25      952.30      952.30         0.0          0.0  organic  2015
# 2015-02-01     1096.03     1096.03         0.0          0.0  organic  2015
#
#             region
# Date
# 2015-01-04  Albany
# 2015-01-11  Albany
# ...

# %%
#plot
albany_df['AveragePrice'].plot()

# %%
albany_df.sort_index(inplace=True)

# %%
albany_df["AveragePrice"].rolling(25).mean().plot()

# %%
#Visual if we want to save our new, smoother, data like above? We can give it a new column in our dataframe:
albany_df["price25ma"] = albany_df["AveragePrice"].rolling(25).mean()
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
albany_df.head()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume   4046    4225  4770  \
# Date
# 2015-01-04          51          1.79       1373.95  57.42  153.88   0.0
# 2015-01-11          50          1.77       1182.56  39.00  305.12   0.0
# 2015-01-18          49          1.93       1118.47   8.02  178.78   0.0
# 2015-01-25          48          1.89       1115.89  14.87  148.72   0.0
# 2015-02-01          47          1.83       1228.51  33.12   99.36   0.0
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# Date
# 2015-01-04     1162.65     1162.65         0.0          0.0  organic  2015
# 2015-01-11      838.44      838.44         0.0          0.0  organic  2015
# 2015-01-18      931.67      931.67         0.0          0.0  organic  2015
# 2015-01-25      952.30      952.30         0.0          0.0  organic  2015
# 2015-02-01     1096.03     1096.03         0.0          0.0  organic  2015
#
#             region  price25ma
# Date
# ...

# %%
albany_df.tail()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume    4046    4225  4770  \
# Date
# 2018-02-25           4          1.56       5356.63  816.56  532.59   0.0
# 2018-03-04           3          1.48       3851.30  311.55  296.77   0.0
# 2018-03-11           2          1.68       2570.52  131.67  229.56   0.0
# 2018-03-18           1          1.66       3154.45  275.89  297.96   0.0
# 2018-03-25           0          1.71       2321.82   42.95  272.41   0.0
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# Date
# 2018-02-25     4007.48     4007.48        0.00          0.0  organic  2018
# 2018-03-04     3242.98     3239.65        3.33          0.0  organic  2018
# 2018-03-11     2209.29     2209.29        0.00          0.0  organic  2018
# 2018-03-18     2580.60     2577.27        3.33          0.0  organic  2018
# 2018-03-25     2006.46     1996.46       10.00          0.0  organic  2018
#
#             region  price25ma
# Date
# ...

# %%
#graph prices for each region.
#df['region']for all region .unique() to get  unique
#df['region'].values covert to array
#df['region'].values.tolist() to list
graph_df = pd.DataFrame()

for region in df['region'].unique():
    region_df = df.copy()[df['region']==region]
    region_df.set_index('Date', inplace=True)
    region_df.sort_index(inplace=True)
    region_df[f"{region}_price25ma"] = region_df["AveragePrice"].rolling(25).mean()

    if graph_df.empty:
        graph_df = region_df[[f"{region}_price25ma"]]  # note the double square brackets! (so df rather than series)
    else:
        graph_df = graph_df.join(region_df[f"{region}_price25ma"])

graph_df.tail()
# Out:
#             California_price25ma  LasVegas_price25ma  PhoenixTucson_price25ma  \
# Date
# 2018-02-25                1.9128              1.9120                   1.7468
# 2018-03-04                1.8876              1.8748                   1.7404
# 2018-03-11                1.8636              1.8440                   1.7324
# 2018-03-18                1.8516              1.8204                   1.7216
# 2018-03-25                1.8364              1.7968                   1.7104
#
#             BuffaloRochester_price25ma  Spokane_price25ma  \
# Date
# 2018-02-25                      1.2912             2.1544
# 2018-03-04                      1.2744             2.1040
# 2018-03-11                      1.2652             2.0552
# 2018-03-18                      1.2560             2.0012
# 2018-03-25                      1.2416             1.9496
#
#             LosAngeles_price25ma  Philadelphia_price25ma  Boston_price25ma  \
# Date
# ...

# %%
#let graph
graph_df.plot(figsize=(8,5), legend=False)

# %%
git init .
# Out:
#   File "<ipython-input-2-bbe88d618c34>", line 1
#     git init .
#            ^
# SyntaxError: invalid syntax
